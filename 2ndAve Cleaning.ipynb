# %%
import pandas,sqlite3

# %%
df1 = pandas.read_csv('counterData/2nd_Ave_Cycle_Track_North_of_Marion_St.csv',
                        usecols = ["Date","2nd Ave Cycletrack","NB","SB"],
                        header = 0,
                     )

# %%
df1.rename(columns=lambda x: x.lstrip(), inplace=True) #strip column names

# %%
df1.rename(columns={'2nd Ave Cycletrack': 'TotalCount'}, inplace=True) #rename for total count

# %%
df1["Name"] = "2ndAveCycleTrack"

# %%
df1["Latitude"]  = 47.605290
df1["Longitude"] = -122.333724

# %%
list(df1.columns.values)
# Out:
# ['Date', 'TotalCount', 'NB', 'SB', 'Name', 'Latitude', 'Longitude']

# %%
df1 = df1[['Name','Date', 'Latitude', 'Longitude', 'NB', 'SB', 'TotalCount']]

# %%
db = sqlite3.connect('cleanedCounterData/bikes.db')
df1.to_sql('BIKECOUNT', db, if_exists='append', index=False)

# %%
df1.to_csv('cleanedCounterData/2ndAveMarionClean.csv')

# %%
df1
# Out:
#                    Name                    Date  Latitude   Longitude    NB  \
# 0      2ndAveCycleTrack  01/01/2015 12:00:00 AM  47.60529 -122.333724   0.0
# 1      2ndAveCycleTrack  01/01/2015 01:00:00 AM  47.60529 -122.333724   0.0
# 2      2ndAveCycleTrack  01/01/2015 02:00:00 AM  47.60529 -122.333724   0.0
# 3      2ndAveCycleTrack  01/01/2015 03:00:00 AM  47.60529 -122.333724   0.0
# 4      2ndAveCycleTrack  01/01/2015 04:00:00 AM  47.60529 -122.333724   0.0
# 5      2ndAveCycleTrack  01/01/2015 05:00:00 AM  47.60529 -122.333724   0.0
# 6      2ndAveCycleTrack  01/01/2015 06:00:00 AM  47.60529 -122.333724   1.0
# 7      2ndAveCycleTrack  01/01/2015 07:00:00 AM  47.60529 -122.333724   1.0
# 8      2ndAveCycleTrack  01/01/2015 08:00:00 AM  47.60529 -122.333724   0.0
# 9      2ndAveCycleTrack  01/01/2015 09:00:00 AM  47.60529 -122.333724   0.0
# 10     2ndAveCycleTrack  01/01/2015 10:00:00 AM  47.60529 -122.333724   2.0
# ...
