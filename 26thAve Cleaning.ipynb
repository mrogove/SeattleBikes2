# %%
import pandas,sqlite3

# %%
df1 = pandas.read_csv('counterData/26th_Ave_SW_Greenway_at_SW_Oregon_St.csv',
                        usecols = ["Date","26th Ave SW Greenway at SW Oregon St Total","North","South"],
                        header = 0,
                     )

# %%
df1.rename(columns=lambda x: x.lstrip(), inplace=True) #strip column names

# %%
df1.rename(columns={'26th Ave SW Greenway at SW Oregon St Total': 'TotalCount', 'North':'NB','South':'SB'}, inplace=True) #rename for total count

# %%
df1["Name"] = "26thAveGreenway"

# %%
df1["Latitude"]  = 47.562888
df1["Longitude"] = -122.365446

# %%
df1 = df1[['Name','Date', 'Latitude', 'Longitude', 'NB', 'SB', 'TotalCount']]

# %%
# db = sqlite3.connect('cleanedCounterData/bikes.db')
# df1.to_sql('BIKECOUNT', db, if_exists='append', index=False)

# %%
df1.to_csv('cleanedCounterData/26thAvenueGreenway.csv')

# %%
df1
# Out:
#                   Name                    Date   Latitude   Longitude   NB  \
# 0      26thAveGreenway  01/01/2014 12:00:00 AM  47.562888 -122.365446  2.0
# 1      26thAveGreenway  01/01/2014 01:00:00 AM  47.562888 -122.365446  0.0
# 2      26thAveGreenway  01/01/2014 02:00:00 AM  47.562888 -122.365446  1.0
# 3      26thAveGreenway  01/01/2014 03:00:00 AM  47.562888 -122.365446  1.0
# 4      26thAveGreenway  01/01/2014 04:00:00 AM  47.562888 -122.365446  1.0
# 5      26thAveGreenway  01/01/2014 05:00:00 AM  47.562888 -122.365446  0.0
# 6      26thAveGreenway  01/01/2014 06:00:00 AM  47.562888 -122.365446  0.0
# 7      26thAveGreenway  01/01/2014 07:00:00 AM  47.562888 -122.365446  0.0
# 8      26thAveGreenway  01/01/2014 08:00:00 AM  47.562888 -122.365446  0.0
# 9      26thAveGreenway  01/01/2014 09:00:00 AM  47.562888 -122.365446  2.0
# 10     26thAveGreenway  01/01/2014 10:00:00 AM  47.562888 -122.365446  2.0
# ...
